# %% [markdown]
# # Face Generation
#
# In this project, you'll define and train a DCGAN on a dataset of faces. Your goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
# The project will be broken down into a series of tasks from **loading in data to defining and training adversarial networks**. At the end of the notebook, you'll be able to visualize the results of your trained Generator to see how it performs; your generated samples should look like fairly realistic faces with small amounts of noise.
#
# ### Get the Data
#
# You'll be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train your adversarial networks.
#
# This dataset is more complex than the number datasets (like MNIST or SVHN) you've been working with, and so, you should prepare to define deeper networks and train them for a longer time to get good results. It is suggested that you utilize a GPU for training.
#
# ### Pre-processed Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. Some sample data is show below.
#
# <img src='assets/processed_face_data.png' width=60% />
#
# > If you are working locally, you can download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip)
#
# This is a zip file that you'll need to extract in the home directory of this notebook for further loading and processing. After extracting the data, you should be left with a directory of data `processed_celeba_small/`

# %%
# can comment out after executing
#!unzip processed_celeba_small.zip

# %%
data_dir = 'processed_celeba_small/'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import problem_unittests as tests
#import helper

# %matplotlib inline

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
# necessary imports
import torch
from torchvision import datasets
from torchvision import transforms
from torch.utils.data import DataLoader

# %%
def get_dataloader(batch_size=32, image_size=64, data_dir='processed_celeba_small/'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param image_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    num_workers = 0
    
    tf = transforms.Compose([transforms.Resize(image_size), transforms.ToTensor()])
    
    dataset = datasets.ImageFolder(data_dir, tf)
    
    dataloader = DataLoader(dataset=dataset, batch_size=batch_size, shuffle=True, num_workers=num_workers)
    
    
    return dataloader

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %%
# Define function hyperparameters
batch_size = 32
img_size = 32

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %% [markdown]
# Next, you can view some images! You should seen square images of somewhat-centered faces.
#
# Note: You'll need to convert the Tensor images into a NumPy type and transpose the dimensions to correctly display an image, suggested `imshow` code is below, but it may not be perfect.

# %%
# helper display function
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=20
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
# TODO: Complete the scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    min, max = feature_range
    x = x * (max - min) + min
    
    return x

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1
img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-0.9765)
# Max:  tensor(0.8510)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
class Discriminator(nn.Module):

    def __init__(self, conv_dim):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator, self).__init__()
        
        # Note: this works with kernel_size = 3, but it is not as good.  It allowed generator to
        # produce some grainier images (vertical striations).
        
        kernel_size = 4 
        
        #without some clever initializations, we must assume the raw image is 32x32x3, since
        # image size is not an input here
        image_size = 32

        # complete init function
        self.c1 = nn.Conv2d(3, conv_dim, kernel_size, 2, 1, bias=False)             #output 16x16x64
        
        self.c2 = nn.Conv2d(conv_dim, 2*conv_dim, kernel_size, 2, 1, bias=False)    #output 8x8x128
        self.bn2 = nn.BatchNorm2d(2*conv_dim)
        
        self.c3 = nn.Conv2d(2*conv_dim, 4*conv_dim, kernel_size, 2, 1, bias=False)  #output 4x4x256
        self.bn3 = nn.BatchNorm2d(4*conv_dim)
        #num_fc_inputs = 4*conv_dim * (image_size//8)**2
        
        self.c4 = nn.Conv2d(4*conv_dim, 8*conv_dim, kernel_size, 2, 1, bias=False)  #output 2x2x512
        self.bn4 = nn.BatchNorm2d(8*conv_dim)
        num_fc_inputs = 8*conv_dim * (image_size//16)**2
        
        #print("Discriminator init: conv_dim = ", conv_dim, ", num_fc_inputs = ", num_fc_inputs)
        self.fc = nn.Linear(num_fc_inputs, 1)
        

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """
        batch_size = x.shape[0]
        #print("Entering Discriminator.forward: x = ", x.shape, ", batch_size = ", batch_size)
        
        # define feedforward behavior
        x = F.leaky_relu(         self.c1(x), 0.2)
        x = F.leaky_relu(self.bn2(self.c2(x)), 0.2)
        x = F.leaky_relu(self.bn3(self.c3(x)), 0.2)
        x = F.leaky_relu(self.bn4(self.c4(x)), 0.2)
        #print("  after c4, x = ", x.shape)
        
        x = x.view(batch_size, -1)
        x = self.fc(x)
        
        return x


d = Discriminator(10)
print(d)
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(Discriminator)
# Out:
# Discriminator(
#   (c1): Conv2d(3, 10, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (c2): Conv2d(10, 20, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (c3): Conv2d(20, 40, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn3): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (c4): Conv2d(40, 80, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn4): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc): Linear(in_features=320, out_features=1, bias=True)
# )
# Tests Passed

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`

# %%
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        super(Generator, self).__init__()
        
        # Notes: tried using kernel_size = 3, but it gives images of size 3x17x17, which won't work.
        # I don't fully understand how the size & stride interact on the transpose side yet.

        image_size = 32 #this is a requirement!
        kernel_size = 4
        self.conv_dim = conv_dim
        
        num_fc_outputs = 8*conv_dim * (image_size//16)**2
        #num_fc_outputs = 4*conv_dim * (image_size//8)**2
        #print("Entering Generator.init: z_size = ", z_size, ", num_fc_outputs = ", num_fc_outputs)
        self.fc = nn.Linear(z_size, num_fc_outputs)
        
        self.tc1 = nn.ConvTranspose2d(8*conv_dim, 4*conv_dim, kernel_size, 2, 1, bias=False) #output 4x4x40
        self.bn1 = nn.BatchNorm2d(4*conv_dim)
        
        self.tc2 = nn.ConvTranspose2d(4*conv_dim, 2*conv_dim, kernel_size, 2, 1, bias=False) #output 8x8x20
        self.bn2 = nn.BatchNorm2d(2*conv_dim)
        
        self.tc3 = nn.ConvTranspose2d(2*conv_dim, conv_dim, kernel_size, 2, 1, bias=False) #output 16x16x10
        self.bn3 = nn.BatchNorm2d(conv_dim)
        
        self.tc4 = nn.ConvTranspose2d(conv_dim, 3, kernel_size, 2, 1, bias=False) #output 32x32x3
        

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        #print("Entering Generator.forward: x = ", x.shape)
        batch_size = x.shape[0]
        
        # define feedforward behavior
        x = F.relu(self.fc(x))
        #print("  after fc, x = ", x.shape)
        x = x.view(batch_size, -1, 2, 2)         #ASSUME: input image size = 32x32; use 4 or 2 dep on 3/4 layers
        assert(x.shape[1] == 8*self.conv_dim)    #4 or 8, depending on 3 or 4 conv layers
        
        #jas - tried leaky relu initially, but system wasn't working
        x = F.relu(self.bn1(self.tc1(x)))
        x = F.relu(self.bn2(self.tc2(x)))
        x = F.relu(self.bn3(self.tc3(x)))
        
        x = torch.tanh(self.tc4(x))
        #print("  ready to return x = ", x.shape)
        
        return x

g = Generator(100, 10)
print(g)
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# Generator(
#   (fc): Linear(in_features=100, out_features=320, bias=True)
#   (tc1): ConvTranspose2d(80, 40, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (tc2): ConvTranspose2d(40, 20, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (tc3): ConvTranspose2d(20, 10, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn3): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (tc4): ConvTranspose2d(10, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
# )
# Tests Passed

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, you should initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
#
# So, your next task will be to define a weight initialization function that does just this!
#
# You can refer back to the lesson on weight initialization or even consult existing model code, such as that from [the `networks.py` file in CycleGAN Github repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py) to help you complete this function.
#
# #### Exercise: Complete the weight initialization function
#
# * This should initialize only **convolutional** and **linear** layers
# * Initialize the weights to a normal distribution, centered around 0, with a standard deviation of 0.02.
# * The bias terms, if they exist, may be left alone or set to 0.

# %%
from torch.nn import init

def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    stdev = 0.02
    
    ##########
    # Code below taken from https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py
    
    if hasattr(m, 'weight') and (classname.find('Conv') != -1 or classname.find('Linear') != -1):
        init.normal_(m.weight.data, 0.0, stdev)
        if hasattr(m, 'bias') and m.bias is not None:
            init.constant_(m.bias.data, 0.0)
    elif classname.find('BatchNorm2d') != -1:  # BatchNorm Layer's weight is not a matrix; only normal distribution applies.
        init.normal_(m.weight.data, 1.0, stdev)
        init.constant_(m.bias.data, 0.0)

# %% [markdown]
# ## Build complete network
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print()
    print(G)
    
    return D, G

# %% [markdown]
# #### Exercise: Define model hyperparameters

# %%
# Define model hyperparams
d_conv_dim = 64
g_conv_dim = 64
z_size = 100

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator(
#   (c1): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (c2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (c3): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (c4): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc): Linear(in_features=2048, out_features=1, bias=True)
# )
#
# Generator(
#   (fc): Linear(in_features=100, out_features=2048, bias=True)
#   (tc1): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (tc2): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (tc3): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (tc4): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
# )

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import torch

# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')
# Out:
# Training on GPU!

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
def real_loss(D_out):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    
    #jas - initial attempt was MSE like in the cycleGAN homework; didn't converge
    #loss = torch.mean((D_out - 1.0)**2)
    D_out = D_out.squeeze()
    ones = torch.ones(*D_out.shape, dtype=torch.float32)
    if train_on_gpu:
        ones = ones.cuda()
    criterion = nn.BCEWithLogitsLoss()
    loss = criterion(D_out, ones)
    return loss

def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''

    #jas - initial attempt was MSE like in the cycleGAN homework; didn't converge
    #loss = torch.mean(D_out*D_out)
    D_out = D_out.squeeze()
    zeros = torch.zeros(*D_out.shape, dtype=torch.float32)
    if train_on_gpu:
        zeros = zeros.cuda()
    criterion = nn.BCEWithLogitsLoss()
    loss = criterion(D_out, zeros)
    return loss

# %%
'''
arr = [-0.4, 0.2, 0.2]
v = torch.tensor(arr).cuda()

lr = real_loss(v)
lf = fake_loss(v)
print("lr = ", lr)
print("lf = ", lf)
'''
# Out:
# '\narr = [-0.4, 0.2, 0.2]\nv = torch.tensor(arr).cuda()\n\nlr = real_loss(v)\nlf = fake_loss(v)\nprint("lr = ", lr)\nprint("lf = ", lf)\n'

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models with appropriate hyperparameters.

# %%
import torch.optim as optim

# Create optimizers for the discriminator D and generator G
# params recommended in https://arxiv.org/pdf/1703.10593.pdf
lr = 0.0005
beta1 = 0.5
beta2 = 0.999

d_optimizer = optim.Adam(D.parameters(), lr, [beta1, beta2])
g_optimizer = optim.Adam(G.parameters(), lr, [beta1, beta2])

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %% [markdown]
# #### Exercise: Complete the training function
#
# Keep in mind that, if you've moved your models to GPU, you'll also have to move any model inputs to GPU.

# %%
def train(D, G, n_epochs, print_every=1):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if train_on_gpu:
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    print("Begining training for {} epochs of {} batches each.".format(n_epochs, len(celeba_train_loader)))
    for epoch in range(n_epochs):

        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)
            real_images = scale(real_images)
            if train_on_gpu:
                real_images = real_images.cuda()

            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================
            
            # 0. Generate a batch of fake images
            # Generator final layer has a tanh activation, so values are guaranteed to be within [-1, 1],
            # so we don't need to scale.  Generator needs to learn to use the full range.
            z = torch.rand([batch_size, z_size])
            if train_on_gpu:
                z = z.cuda()
            z = scale(z)
            fake_images = G(z)
            #fake_images = scale(fake_images)
            
            # 1. Train the discriminator on real and fake images
            d_optimizer.zero_grad()
            
            d_out_real = D(real_images)
            d_loss_real = real_loss(d_out_real)
            
            d_out_fake = D(fake_images)
            d_loss_fake = fake_loss(d_out_fake)
            
            d_loss = d_loss_real + d_loss_fake
            d_loss.backward()
            d_optimizer.step()

            #'''
            # 2. Train the generator with an adversarial loss
            g_optimizer.zero_grad()
            
            z = torch.rand([batch_size, z_size])
            if train_on_gpu:
                z = z.cuda()
            z = scale(z)
            #print("z going into generator training =\n", z[0])
            
            fake_images = G(z) #need to do again so backprop doesn't get lost
            #print("raw fake_image =\n", fake_images[0])
            
            #fake_images = scale(fake_images)
            g_d_out = D(fake_images)
            #print("g_d_out =\n", g_d_out)
            
            g_loss = real_loss(g_d_out)
            #print("g_loss =\n", g_loss)
            
            g_loss.backward()
            g_optimizer.step()
            #'''
            #g_loss = d_loss
            #g_d_out = 0
            
            
            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                
                #print("d_out_real = ", d_out_real)
                #print("d_out_fake = ", d_out_fake)
                #print("g_d_out min/max = {:.2f} / {:.2f}".format(torch.min(g_d_out).item(), torch.max(g_d_out).item()))
                
                # print discriminator and generator loss
                print('Epoch {:4d}/{:4d} | d_loss: {:6.4f} | g_loss: {:6.4f}; g_d_out min/max = {:.2f} / {:.2f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item(), torch.min(g_d_out).item(),
                        torch.max(g_d_out).item()))
                #print()


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        samples_z = G(fixed_z)
        samples.append(samples_z)
        G.train() # back to training mode

    # Save training generator samples
    with open('train_samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
# set number of epochs 
n_epochs = 50
print_every = 100


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function
losses = train(D, G, n_epochs=n_epochs, print_every=print_every)
# Out:
# Begining training for 50 epochs of 1019 batches each.
# Epoch    1/  50 | d_loss: 1.9295 | g_loss: 5.8163; g_d_out min/max = -6.76 / -5.05
# Epoch    1/  50 | d_loss: 1.0539 | g_loss: 5.8572; g_d_out min/max = -6.90 / -4.71
# Epoch    1/  50 | d_loss: 0.7255 | g_loss: 3.0702; g_d_out min/max = -4.32 / -2.00
# Epoch    1/  50 | d_loss: 0.4332 | g_loss: 2.4565; g_d_out min/max = -4.22 / -1.04
# Epoch    1/  50 | d_loss: 0.6241 | g_loss: 2.0904; g_d_out min/max = -2.99 / 0.13
# Epoch    1/  50 | d_loss: 0.9681 | g_loss: 3.3744; g_d_out min/max = -5.46 / -1.60
# Epoch    1/  50 | d_loss: 1.0729 | g_loss: 4.8421; g_d_out min/max = -7.02 / -2.47
# Epoch    1/  50 | d_loss: 2.1285 | g_loss: 5.2814; g_d_out min/max = -8.32 / -3.87
# Epoch    1/  50 | d_loss: 0.3363 | g_loss: 2.8529; g_d_out min/max = -4.42 / -0.96
# Epoch    1/  50 | d_loss: 0.7353 | g_loss: 3.9882; g_d_out min/max = -6.39 / -1.94
# Epoch    1/  50 | d_loss: 0.6250 | g_loss: 3.1760; g_d_out min/max = -7.15 / -1.06
# Epoch    2/  50 | d_loss: 0.8335 | g_loss: 2.7971; g_d_out min/max = -5.32 / -0.88
# Epoch    2/  50 | d_loss: 0.5061 | g_loss: 2.5869; g_d_out min/max = -4.28 / 0.56
# Epoch    2/  50 | d_loss: 1.3706 | g_loss: 5.4953; g_d_out min/max = -9.75 / -2.44
# Epoch    2/  50 | d_loss: 0.5841 | g_loss: 3.0472; g_d_out min/max = -5.32 / -1.18
# Epoch    2/  50 | d_loss: 1.0433 | g_loss: 1.4549; g_d_out min/max = -3.93 / 0.81
# Epoch    2/  50 | d_loss: 1.2807 | g_loss: 1.1532; g_d_out min/max = -1.95 / 0.83
# Epoch    2/  50 | d_loss: 0.7221 | g_loss: 2.8625; g_d_out min/max = -5.28 / -0.76
# Epoch    2/  50 | d_loss: 0.9867 | g_loss: 5.0582; g_d_out min/max = -7.02 / -2.79
# Epoch    2/  50 | d_loss: 0.8070 | g_loss: 1.6832; g_d_out min/max = -2.92 / 0.19
# Epoch    2/  50 | d_loss: 0.4471 | g_loss: 3.5037; g_d_out min/max = -5.32 / -1.59
# Epoch    2/  50 | d_loss: 0.4133 | g_loss: 3.7660; g_d_out min/max = -6.06 / -2.39
# Epoch    3/  50 | d_loss: 0.5466 | g_loss: 2.4953; g_d_out min/max = -4.65 / -0.12
# Epoch    3/  50 | d_loss: 0.8386 | g_loss: 2.7815; g_d_out min/max = -4.27 / -1.31
# Epoch    3/  50 | d_loss: 0.4728 | g_loss: 2.7479; g_d_out min/max = -3.71 / -0.52
# Epoch    3/  50 | d_loss: 1.4768 | g_loss: 2.7010; g_d_out min/max = -5.30 / -0.31
# Epoch    3/  50 | d_loss: 1.2471 | g_loss: 1.8533; g_d_out min/max = -3.15 / 0.09
# Epoch    3/  50 | d_loss: 0.7557 | g_loss: 2.0278; g_d_out min/max = -4.06 / 1.11
# Epoch    3/  50 | d_loss: 0.6320 | g_loss: 3.3444; g_d_out min/max = -5.62 / -1.26
# Epoch    3/  50 | d_loss: 1.1386 | g_loss: 4.7767; g_d_out min/max = -7.57 / 0.76
# Epoch    3/  50 | d_loss: 1.3091 | g_loss: 4.0759; g_d_out min/max = -5.59 / -2.58
# Epoch    3/  50 | d_loss: 0.8307 | g_loss: 3.6935; g_d_out min/max = -5.78 / -1.81
# Epoch    3/  50 | d_loss: 0.6787 | g_loss: 2.8211; g_d_out min/max = -4.86 / -0.81
# Epoch    4/  50 | d_loss: 0.7202 | g_loss: 1.7557; g_d_out min/max = -3.79 / 0.62
# Epoch    4/  50 | d_loss: 0.8215 | g_loss: 2.4313; g_d_out min/max = -5.59 / -0.27
# Epoch    4/  50 | d_loss: 0.9078 | g_loss: 3.9890; g_d_out min/max = -5.71 / -1.99
# Epoch    4/  50 | d_loss: 0.8874 | g_loss: 3.4380; g_d_out min/max = -5.64 / -0.66
# Epoch    4/  50 | d_loss: 1.1794 | g_loss: 1.4190; g_d_out min/max = -4.31 / 0.74
# Epoch    4/  50 | d_loss: 0.7921 | g_loss: 1.8014; g_d_out min/max = -4.45 / 0.94
# Epoch    4/  50 | d_loss: 0.9457 | g_loss: 1.5616; g_d_out min/max = -3.74 / 0.80
# Epoch    4/  50 | d_loss: 0.5660 | g_loss: 3.6880; g_d_out min/max = -6.16 / -2.08
# Epoch    4/  50 | d_loss: 0.7137 | g_loss: 1.9805; g_d_out min/max = -4.21 / 0.38
# Epoch    4/  50 | d_loss: 0.9919 | g_loss: 1.8678; g_d_out min/max = -3.78 / 0.62
# Epoch    4/  50 | d_loss: 0.9341 | g_loss: 1.9490; g_d_out min/max = -5.24 / -0.51
# Epoch    5/  50 | d_loss: 1.8779 | g_loss: 3.8751; g_d_out min/max = -8.31 / -1.23
# Epoch    5/  50 | d_loss: 0.7449 | g_loss: 2.0048; g_d_out min/max = -3.34 / 1.72
# Epoch    5/  50 | d_loss: 0.8357 | g_loss: 4.0807; g_d_out min/max = -6.14 / -1.84
# Epoch    5/  50 | d_loss: 0.8240 | g_loss: 2.8757; g_d_out min/max = -5.14 / -0.56
# Epoch    5/  50 | d_loss: 1.1592 | g_loss: 2.1318; g_d_out min/max = -3.54 / -0.13
# Epoch    5/  50 | d_loss: 0.9290 | g_loss: 1.8927; g_d_out min/max = -3.44 / 0.82
# Epoch    5/  50 | d_loss: 0.6316 | g_loss: 2.4493; g_d_out min/max = -4.84 / -0.04
# Epoch    5/  50 | d_loss: 0.9732 | g_loss: 1.1571; g_d_out min/max = -2.47 / 1.84
# Epoch    5/  50 | d_loss: 1.6849 | g_loss: 3.7395; g_d_out min/max = -6.35 / -2.02
# Epoch    5/  50 | d_loss: 0.9258 | g_loss: 3.3495; g_d_out min/max = -4.70 / -1.58
# Epoch    5/  50 | d_loss: 0.6581 | g_loss: 2.4638; g_d_out min/max = -6.53 / 0.34
# Epoch    6/  50 | d_loss: 0.6116 | g_loss: 3.8706; g_d_out min/max = -7.34 / -0.88
# Epoch    6/  50 | d_loss: 0.7816 | g_loss: 1.4946; g_d_out min/max = -3.15 / 1.31
# Epoch    6/  50 | d_loss: 0.9009 | g_loss: 1.7610; g_d_out min/max = -3.86 / 1.84
# Epoch    6/  50 | d_loss: 0.8266 | g_loss: 2.1576; g_d_out min/max = -4.92 / 0.41
# Epoch    6/  50 | d_loss: 1.1812 | g_loss: 4.1954; g_d_out min/max = -6.16 / -1.77
# Epoch    6/  50 | d_loss: 0.6969 | g_loss: 1.5632; g_d_out min/max = -3.32 / 1.05
# Epoch    6/  50 | d_loss: 0.5633 | g_loss: 3.1358; g_d_out min/max = -5.38 / -1.05
# Epoch    6/  50 | d_loss: 0.8044 | g_loss: 3.3905; g_d_out min/max = -5.28 / -1.02
# Epoch    6/  50 | d_loss: 0.8342 | g_loss: 2.6114; g_d_out min/max = -4.34 / 1.58
# Epoch    6/  50 | d_loss: 0.9531 | g_loss: 2.3541; g_d_out min/max = -3.75 / -0.22
# Epoch    6/  50 | d_loss: 0.9007 | g_loss: 1.7102; g_d_out min/max = -4.82 / 1.18
# Epoch    7/  50 | d_loss: 0.8121 | g_loss: 1.9023; g_d_out min/max = -3.75 / 1.40
# Epoch    7/  50 | d_loss: 0.9714 | g_loss: 0.7456; g_d_out min/max = -3.00 / 1.66
# Epoch    7/  50 | d_loss: 1.0039 | g_loss: 3.2456; g_d_out min/max = -4.88 / -0.50
# Epoch    7/  50 | d_loss: 1.2600 | g_loss: 1.5436; g_d_out min/max = -5.80 / 1.70
# Epoch    7/  50 | d_loss: 0.7654 | g_loss: 1.3926; g_d_out min/max = -3.26 / 0.78
# Epoch    7/  50 | d_loss: 0.6416 | g_loss: 2.2897; g_d_out min/max = -4.60 / -0.21
# Epoch    7/  50 | d_loss: 1.5288 | g_loss: 3.0021; g_d_out min/max = -5.50 / -0.62
# Epoch    7/  50 | d_loss: 0.8108 | g_loss: 2.1476; g_d_out min/max = -4.66 / 0.42
# Epoch    7/  50 | d_loss: 0.7096 | g_loss: 2.7832; g_d_out min/max = -4.91 / 0.88
# Epoch    7/  50 | d_loss: 0.8606 | g_loss: 1.9947; g_d_out min/max = -4.46 / 0.01
# Epoch    7/  50 | d_loss: 1.1617 | g_loss: 2.0747; g_d_out min/max = -4.69 / 0.90
# Epoch    8/  50 | d_loss: 0.6988 | g_loss: 2.4185; g_d_out min/max = -4.29 / -0.40
# Epoch    8/  50 | d_loss: 1.3364 | g_loss: 0.7519; g_d_out min/max = -3.11 / 3.54
# Epoch    8/  50 | d_loss: 0.6341 | g_loss: 2.7062; g_d_out min/max = -5.68 / -0.18
# Epoch    8/  50 | d_loss: 0.6267 | g_loss: 3.1150; g_d_out min/max = -6.33 / -1.11
# Epoch    8/  50 | d_loss: 0.6520 | g_loss: 2.1782; g_d_out min/max = -4.64 / 0.29
# Epoch    8/  50 | d_loss: 1.0637 | g_loss: 2.6966; g_d_out min/max = -5.71 / 0.25
# Epoch    8/  50 | d_loss: 0.8379 | g_loss: 2.1420; g_d_out min/max = -3.87 / -0.04
# Epoch    8/  50 | d_loss: 0.7829 | g_loss: 1.7652; g_d_out min/max = -4.62 / 1.56
# Epoch    8/  50 | d_loss: 0.7544 | g_loss: 2.4829; g_d_out min/max = -5.96 / 0.29
# Epoch    8/  50 | d_loss: 0.9599 | g_loss: 1.4391; g_d_out min/max = -2.78 / 2.45
# Epoch    8/  50 | d_loss: 1.1187 | g_loss: 1.5989; g_d_out min/max = -3.07 / 1.09
# Epoch    9/  50 | d_loss: 0.6153 | g_loss: 2.8394; g_d_out min/max = -4.90 / -1.14
# Epoch    9/  50 | d_loss: 0.9105 | g_loss: 2.0519; g_d_out min/max = -4.44 / -0.09
# Epoch    9/  50 | d_loss: 0.7934 | g_loss: 2.2456; g_d_out min/max = -4.35 / 0.32
# Epoch    9/  50 | d_loss: 1.0374 | g_loss: 1.6892; g_d_out min/max = -4.18 / 1.20
# Epoch    9/  50 | d_loss: 0.7333 | g_loss: 1.7869; g_d_out min/max = -4.47 / 1.09
# Epoch    9/  50 | d_loss: 1.4253 | g_loss: 1.2075; g_d_out min/max = -2.63 / 1.79
# Epoch    9/  50 | d_loss: 0.6623 | g_loss: 3.0331; g_d_out min/max = -8.06 / -0.83
# Epoch    9/  50 | d_loss: 0.7021 | g_loss: 1.8538; g_d_out min/max = -3.67 / 0.24
# Epoch    9/  50 | d_loss: 0.6247 | g_loss: 2.8616; g_d_out min/max = -4.79 / -0.96
# Epoch    9/  50 | d_loss: 1.0102 | g_loss: 1.9338; g_d_out min/max = -4.13 / 0.59
# Epoch    9/  50 | d_loss: 1.2022 | g_loss: 1.0214; g_d_out min/max = -2.84 / 2.30
# Epoch   10/  50 | d_loss: 0.5506 | g_loss: 1.6020; g_d_out min/max = -3.91 / 1.07
# Epoch   10/  50 | d_loss: 1.1657 | g_loss: 3.0106; g_d_out min/max = -5.25 / 1.58
# Epoch   10/  50 | d_loss: 0.7523 | g_loss: 4.2711; g_d_out min/max = -6.92 / -1.10
# Epoch   10/  50 | d_loss: 0.8600 | g_loss: 2.7040; g_d_out min/max = -5.01 / -0.50
# Epoch   10/  50 | d_loss: 0.8456 | g_loss: 1.3298; g_d_out min/max = -2.90 / 0.48
# Epoch   10/  50 | d_loss: 0.8601 | g_loss: 2.7829; g_d_out min/max = -8.05 / -0.47
# Epoch   10/  50 | d_loss: 0.7063 | g_loss: 2.4379; g_d_out min/max = -5.36 / -0.14
# Epoch   10/  50 | d_loss: 0.6225 | g_loss: 2.6915; g_d_out min/max = -6.85 / 0.68
# Epoch   10/  50 | d_loss: 0.7872 | g_loss: 3.1391; g_d_out min/max = -6.28 / 0.25
# Epoch   10/  50 | d_loss: 1.3462 | g_loss: 2.9599; g_d_out min/max = -5.43 / -0.89
# Epoch   10/  50 | d_loss: 1.3221 | g_loss: 2.0708; g_d_out min/max = -4.20 / 0.97
# Epoch   11/  50 | d_loss: 0.4823 | g_loss: 1.7047; g_d_out min/max = -4.00 / 0.97
# Epoch   11/  50 | d_loss: 1.0301 | g_loss: 2.5980; g_d_out min/max = -4.47 / -0.38
# Epoch   11/  50 | d_loss: 0.7668 | g_loss: 3.2942; g_d_out min/max = -5.46 / -1.06
# Epoch   11/  50 | d_loss: 0.3624 | g_loss: 2.4679; g_d_out min/max = -5.04 / 0.11
# Epoch   11/  50 | d_loss: 0.6116 | g_loss: 2.6088; g_d_out min/max = -7.36 / 0.09
# Epoch   11/  50 | d_loss: 0.5804 | g_loss: 2.5302; g_d_out min/max = -5.74 / 0.41
# Epoch   11/  50 | d_loss: 0.9106 | g_loss: 2.1993; g_d_out min/max = -5.62 / 0.45
# Epoch   11/  50 | d_loss: 0.6468 | g_loss: 2.6426; g_d_out min/max = -8.02 / 0.17
# Epoch   11/  50 | d_loss: 0.6730 | g_loss: 1.1114; g_d_out min/max = -2.52 / 1.42
# Epoch   11/  50 | d_loss: 0.5740 | g_loss: 3.1769; g_d_out min/max = -7.18 / 1.14
# Epoch   11/  50 | d_loss: 0.9905 | g_loss: 2.7501; g_d_out min/max = -7.10 / -0.44
# Epoch   12/  50 | d_loss: 0.8123 | g_loss: 1.6916; g_d_out min/max = -4.34 / 2.32
# Epoch   12/  50 | d_loss: 0.7783 | g_loss: 2.9698; g_d_out min/max = -6.19 / 1.09
# Epoch   12/  50 | d_loss: 1.6241 | g_loss: 4.7862; g_d_out min/max = -7.04 / -0.33
# Epoch   12/  50 | d_loss: 0.3833 | g_loss: 3.2503; g_d_out min/max = -5.98 / -1.41
# Epoch   12/  50 | d_loss: 0.8202 | g_loss: 4.8286; g_d_out min/max = -8.59 / -2.31
# Epoch   12/  50 | d_loss: 1.0207 | g_loss: 2.2225; g_d_out min/max = -5.33 / 0.46
# Epoch   12/  50 | d_loss: 0.5300 | g_loss: 3.3753; g_d_out min/max = -7.25 / 0.74
# Epoch   12/  50 | d_loss: 0.4127 | g_loss: 1.8199; g_d_out min/max = -3.86 / 0.88
# Epoch   12/  50 | d_loss: 0.3474 | g_loss: 4.2199; g_d_out min/max = -6.40 / -0.99
# Epoch   12/  50 | d_loss: 0.9315 | g_loss: 1.3163; g_d_out min/max = -4.45 / 2.04
# Epoch   12/  50 | d_loss: 0.6026 | g_loss: 1.3059; g_d_out min/max = -6.06 / 3.23
# Epoch   13/  50 | d_loss: 0.7400 | g_loss: 3.3570; g_d_out min/max = -4.91 / 1.26
# Epoch   13/  50 | d_loss: 0.8602 | g_loss: 3.2541; g_d_out min/max = -5.08 / -1.39
# Epoch   13/  50 | d_loss: 0.8151 | g_loss: 1.5493; g_d_out min/max = -3.36 / 0.99
# Epoch   13/  50 | d_loss: 0.5550 | g_loss: 2.1050; g_d_out min/max = -4.56 / 0.59
# Epoch   13/  50 | d_loss: 0.4486 | g_loss: 3.2670; g_d_out min/max = -7.06 / -0.19
# Epoch   13/  50 | d_loss: 0.2815 | g_loss: 1.7952; g_d_out min/max = -5.42 / 1.04
# Epoch   13/  50 | d_loss: 0.8024 | g_loss: 2.9762; g_d_out min/max = -5.13 / -0.55
# Epoch   13/  50 | d_loss: 0.4931 | g_loss: 2.4755; g_d_out min/max = -6.24 / 0.44
# Epoch   13/  50 | d_loss: 1.0440 | g_loss: 3.2145; g_d_out min/max = -7.39 / -0.14
# Epoch   13/  50 | d_loss: 0.5288 | g_loss: 3.2341; g_d_out min/max = -7.76 / -0.64
# Epoch   13/  50 | d_loss: 1.3210 | g_loss: 1.0930; g_d_out min/max = -3.67 / 2.54
# Epoch   14/  50 | d_loss: 0.4348 | g_loss: 3.4391; g_d_out min/max = -5.04 / -0.98
# Epoch   14/  50 | d_loss: 0.5952 | g_loss: 3.2752; g_d_out min/max = -7.14 / -0.49
# Epoch   14/  50 | d_loss: 1.0141 | g_loss: 2.7377; g_d_out min/max = -6.56 / 1.24
# Epoch   14/  50 | d_loss: 0.3877 | g_loss: 2.8382; g_d_out min/max = -7.02 / -0.23
# Epoch   14/  50 | d_loss: 0.8147 | g_loss: 2.6935; g_d_out min/max = -4.52 / -0.30
# Epoch   14/  50 | d_loss: 0.4461 | g_loss: 3.0325; g_d_out min/max = -5.72 / 0.18
# Epoch   14/  50 | d_loss: 0.5043 | g_loss: 3.0428; g_d_out min/max = -5.38 / 0.10
# Epoch   14/  50 | d_loss: 0.4426 | g_loss: 1.1060; g_d_out min/max = -4.04 / 1.88
# Epoch   14/  50 | d_loss: 0.7099 | g_loss: 3.2936; g_d_out min/max = -6.11 / 0.23
# Epoch   14/  50 | d_loss: 0.6137 | g_loss: 1.1338; g_d_out min/max = -2.76 / 2.25
# Epoch   14/  50 | d_loss: 0.6300 | g_loss: 3.7872; g_d_out min/max = -6.83 / -1.03
# Epoch   15/  50 | d_loss: 0.6309 | g_loss: 3.5354; g_d_out min/max = -6.45 / -0.17
# Epoch   15/  50 | d_loss: 0.3363 | g_loss: 3.3586; g_d_out min/max = -6.93 / -1.33
# Epoch   15/  50 | d_loss: 0.3718 | g_loss: 2.0643; g_d_out min/max = -7.07 / 0.40
# Epoch   15/  50 | d_loss: 0.9149 | g_loss: 3.2521; g_d_out min/max = -6.76 / 0.34
# Epoch   15/  50 | d_loss: 0.6802 | g_loss: 4.4455; g_d_out min/max = -9.04 / -2.93
# Epoch   15/  50 | d_loss: 0.6412 | g_loss: 3.9881; g_d_out min/max = -7.43 / 0.14
# Epoch   15/  50 | d_loss: 0.7466 | g_loss: 2.7819; g_d_out min/max = -8.52 / 1.80
# Epoch   15/  50 | d_loss: 1.0252 | g_loss: 3.3567; g_d_out min/max = -7.42 / -0.72
# Epoch   15/  50 | d_loss: 0.9146 | g_loss: 3.4179; g_d_out min/max = -6.43 / 0.05
# Epoch   15/  50 | d_loss: 0.4710 | g_loss: 3.9464; g_d_out min/max = -8.10 / -0.76
# Epoch   15/  50 | d_loss: 0.6005 | g_loss: 4.7135; g_d_out min/max = -8.55 / -2.07
# Epoch   16/  50 | d_loss: 0.3363 | g_loss: 4.1828; g_d_out min/max = -6.83 / -2.23
# Epoch   16/  50 | d_loss: 0.3940 | g_loss: 2.2533; g_d_out min/max = -4.88 / 2.10
# Epoch   16/  50 | d_loss: 0.4151 | g_loss: 4.9337; g_d_out min/max = -10.36 / -2.28
# Epoch   16/  50 | d_loss: 0.8974 | g_loss: 2.7126; g_d_out min/max = -4.52 / -0.32
# Epoch   16/  50 | d_loss: 0.7343 | g_loss: 3.4079; g_d_out min/max = -8.08 / 0.54
# Epoch   16/  50 | d_loss: 0.5444 | g_loss: 3.8037; g_d_out min/max = -6.39 / -1.06
# Epoch   16/  50 | d_loss: 0.3860 | g_loss: 2.5419; g_d_out min/max = -5.02 / 3.26
# Epoch   16/  50 | d_loss: 0.7101 | g_loss: 2.2369; g_d_out min/max = -4.06 / 1.40
# Epoch   16/  50 | d_loss: 0.7594 | g_loss: 3.6308; g_d_out min/max = -6.53 / -0.44
# Epoch   16/  50 | d_loss: 0.7554 | g_loss: 2.4187; g_d_out min/max = -5.47 / 2.40
# Epoch   16/  50 | d_loss: 0.4342 | g_loss: 1.6839; g_d_out min/max = -5.25 / 1.96
# Epoch   17/  50 | d_loss: 0.6484 | g_loss: 2.7673; g_d_out min/max = -6.14 / 0.34
# Epoch   17/  50 | d_loss: 0.8545 | g_loss: 5.0751; g_d_out min/max = -7.55 / -1.20
# Epoch   17/  50 | d_loss: 0.5485 | g_loss: 3.7155; g_d_out min/max = -6.55 / -0.53
# Epoch   17/  50 | d_loss: 0.4385 | g_loss: 5.2357; g_d_out min/max = -9.20 / -2.19
# Epoch   17/  50 | d_loss: 0.4658 | g_loss: 3.2838; g_d_out min/max = -5.36 / -0.72
# Epoch   17/  50 | d_loss: 0.4156 | g_loss: 3.3250; g_d_out min/max = -5.90 / 0.58
# Epoch   17/  50 | d_loss: 0.7154 | g_loss: 3.6686; g_d_out min/max = -6.39 / -0.20
# Epoch   17/  50 | d_loss: 0.1987 | g_loss: 2.7679; g_d_out min/max = -5.23 / 0.35
# Epoch   17/  50 | d_loss: 0.2495 | g_loss: 4.0612; g_d_out min/max = -6.40 / -0.91
# Epoch   17/  50 | d_loss: 0.6420 | g_loss: 2.6100; g_d_out min/max = -11.20 / 1.05
# Epoch   17/  50 | d_loss: 0.5946 | g_loss: 2.3669; g_d_out min/max = -5.68 / 1.64
# Epoch   18/  50 | d_loss: 0.7173 | g_loss: 4.7541; g_d_out min/max = -8.86 / -0.08
# Epoch   18/  50 | d_loss: 0.4840 | g_loss: 3.1651; g_d_out min/max = -6.12 / 0.68
# Epoch   18/  50 | d_loss: 0.4165 | g_loss: 2.3602; g_d_out min/max = -4.56 / 2.12
# Epoch   18/  50 | d_loss: 0.5522 | g_loss: 2.3142; g_d_out min/max = -5.51 / 1.88
# Epoch   18/  50 | d_loss: 0.2526 | g_loss: 2.2475; g_d_out min/max = -6.96 / 1.05
# Epoch   18/  50 | d_loss: 0.2626 | g_loss: 3.8363; g_d_out min/max = -7.12 / -0.54
# Epoch   18/  50 | d_loss: 0.9042 | g_loss: 4.4772; g_d_out min/max = -8.27 / -1.58
# Epoch   18/  50 | d_loss: 1.3133 | g_loss: 1.1755; g_d_out min/max = -3.63 / 1.57
# Epoch   18/  50 | d_loss: 0.3368 | g_loss: 4.3232; g_d_out min/max = -7.99 / -1.95
# Epoch   18/  50 | d_loss: 1.2351 | g_loss: 2.5355; g_d_out min/max = -5.89 / 0.61
# Epoch   18/  50 | d_loss: 0.4167 | g_loss: 3.2222; g_d_out min/max = -7.34 / -0.06
# Epoch   19/  50 | d_loss: 0.7283 | g_loss: 3.0303; g_d_out min/max = -7.54 / 0.04
# Epoch   19/  50 | d_loss: 0.4788 | g_loss: 3.8206; g_d_out min/max = -6.59 / -1.16
# Epoch   19/  50 | d_loss: 0.8815 | g_loss: 1.3997; g_d_out min/max = -4.21 / 2.85
# Epoch   19/  50 | d_loss: 0.5180 | g_loss: 3.0867; g_d_out min/max = -7.42 / -0.37
# Epoch   19/  50 | d_loss: 0.6672 | g_loss: 2.5169; g_d_out min/max = -5.21 / 1.80
# Epoch   19/  50 | d_loss: 0.6128 | g_loss: 2.5377; g_d_out min/max = -7.30 / 2.68
# Epoch   19/  50 | d_loss: 0.1570 | g_loss: 3.8898; g_d_out min/max = -7.14 / -0.55
# Epoch   19/  50 | d_loss: 0.5677 | g_loss: 4.7521; g_d_out min/max = -10.71 / 0.12
# Epoch   19/  50 | d_loss: 0.5932 | g_loss: 4.5811; g_d_out min/max = -7.54 / -2.03
# Epoch   19/  50 | d_loss: 0.4179 | g_loss: 4.3114; g_d_out min/max = -8.27 / -0.64
# Epoch   19/  50 | d_loss: 0.3305 | g_loss: 3.3736; g_d_out min/max = -8.39 / 0.05
# Epoch   20/  50 | d_loss: 0.4780 | g_loss: 3.4129; g_d_out min/max = -8.51 / -0.56
# Epoch   20/  50 | d_loss: 0.8336 | g_loss: 4.4146; g_d_out min/max = -7.38 / 0.61
# Epoch   20/  50 | d_loss: 0.3893 | g_loss: 3.5578; g_d_out min/max = -5.84 / -1.04
# Epoch   20/  50 | d_loss: 0.3256 | g_loss: 4.7738; g_d_out min/max = -6.76 / -2.92
# Epoch   20/  50 | d_loss: 0.2166 | g_loss: 2.9171; g_d_out min/max = -7.41 / 0.88
# Epoch   20/  50 | d_loss: 0.5751 | g_loss: 3.1341; g_d_out min/max = -6.97 / 0.00
# Epoch   20/  50 | d_loss: 0.4020 | g_loss: 2.0569; g_d_out min/max = -4.93 / 0.81
# Epoch   20/  50 | d_loss: 0.8506 | g_loss: 4.9341; g_d_out min/max = -12.58 / -0.82
# Epoch   20/  50 | d_loss: 0.4127 | g_loss: 1.2820; g_d_out min/max = -4.16 / 4.72
# Epoch   20/  50 | d_loss: 0.8512 | g_loss: 1.0380; g_d_out min/max = -4.54 / 3.44
# Epoch   20/  50 | d_loss: 0.2838 | g_loss: 2.3665; g_d_out min/max = -5.15 / 0.65
# Epoch   21/  50 | d_loss: 0.4624 | g_loss: 3.5513; g_d_out min/max = -7.96 / 0.55
# Epoch   21/  50 | d_loss: 0.3048 | g_loss: 3.6269; g_d_out min/max = -7.51 / 1.04
# Epoch   21/  50 | d_loss: 0.4687 | g_loss: 2.5199; g_d_out min/max = -7.40 / 0.84
# Epoch   21/  50 | d_loss: 0.4750 | g_loss: 4.9771; g_d_out min/max = -8.43 / -0.70
# Epoch   21/  50 | d_loss: 0.4641 | g_loss: 3.1264; g_d_out min/max = -6.75 / 0.54
# Epoch   21/  50 | d_loss: 0.4674 | g_loss: 3.8933; g_d_out min/max = -10.23 / -0.49
# Epoch   21/  50 | d_loss: 1.0185 | g_loss: 1.6428; g_d_out min/max = -4.50 / 2.13
# Epoch   21/  50 | d_loss: 0.3379 | g_loss: 4.5426; g_d_out min/max = -8.19 / -0.74
# Epoch   21/  50 | d_loss: 0.3005 | g_loss: 2.8194; g_d_out min/max = -7.32 / 1.97
# Epoch   21/  50 | d_loss: 0.5699 | g_loss: 4.5173; g_d_out min/max = -9.91 / -0.78
# Epoch   21/  50 | d_loss: 0.1377 | g_loss: 4.0457; g_d_out min/max = -8.27 / -2.21
# Epoch   22/  50 | d_loss: 0.6309 | g_loss: 3.9609; g_d_out min/max = -9.60 / -0.49
# Epoch   22/  50 | d_loss: 0.5528 | g_loss: 4.3467; g_d_out min/max = -7.63 / -0.13
# Epoch   22/  50 | d_loss: 0.3439 | g_loss: 2.2704; g_d_out min/max = -5.59 / 1.25
# Epoch   22/  50 | d_loss: 0.2252 | g_loss: 2.2129; g_d_out min/max = -7.12 / 0.77
# Epoch   22/  50 | d_loss: 0.1673 | g_loss: 2.6924; g_d_out min/max = -5.60 / 1.06
# Epoch   22/  50 | d_loss: 0.5563 | g_loss: 2.1867; g_d_out min/max = -4.87 / 0.57
# Epoch   22/  50 | d_loss: 0.3208 | g_loss: 4.8106; g_d_out min/max = -10.00 / -0.42
# Epoch   22/  50 | d_loss: 0.4792 | g_loss: 1.7525; g_d_out min/max = -4.85 / 2.75
# Epoch   22/  50 | d_loss: 0.3361 | g_loss: 2.7230; g_d_out min/max = -7.70 / 0.87
# Epoch   22/  50 | d_loss: 0.2829 | g_loss: 3.2678; g_d_out min/max = -9.65 / 1.44
# Epoch   22/  50 | d_loss: 0.5094 | g_loss: 2.8870; g_d_out min/max = -8.05 / 0.21
# Epoch   23/  50 | d_loss: 0.3943 | g_loss: 4.6723; g_d_out min/max = -9.60 / -0.49
# Epoch   23/  50 | d_loss: 0.6358 | g_loss: 2.0658; g_d_out min/max = -4.59 / 2.81
# Epoch   23/  50 | d_loss: 0.3064 | g_loss: 4.2713; g_d_out min/max = -7.90 / -1.00
# Epoch   23/  50 | d_loss: 0.4446 | g_loss: 3.3152; g_d_out min/max = -10.47 / 1.04
# Epoch   23/  50 | d_loss: 0.1997 | g_loss: 4.7722; g_d_out min/max = -7.92 / -2.09
# Epoch   23/  50 | d_loss: 0.2541 | g_loss: 3.7297; g_d_out min/max = -7.79 / -0.45
# Epoch   23/  50 | d_loss: 0.1659 | g_loss: 4.2997; g_d_out min/max = -8.47 / -1.57
# Epoch   23/  50 | d_loss: 0.1079 | g_loss: 2.4572; g_d_out min/max = -6.79 / 1.44
# Epoch   23/  50 | d_loss: 0.1151 | g_loss: 2.4807; g_d_out min/max = -8.28 / 1.38
# Epoch   23/  50 | d_loss: 0.2265 | g_loss: 2.3423; g_d_out min/max = -6.13 / 0.41
# Epoch   23/  50 | d_loss: 0.4119 | g_loss: 3.2389; g_d_out min/max = -6.43 / 0.26
# Epoch   24/  50 | d_loss: 0.2062 | g_loss: 2.7773; g_d_out min/max = -5.63 / -0.25
# Epoch   24/  50 | d_loss: 0.2783 | g_loss: 3.4141; g_d_out min/max = -6.67 / 3.46
# Epoch   24/  50 | d_loss: 0.2376 | g_loss: 3.9181; g_d_out min/max = -11.74 / 0.34
# Epoch   24/  50 | d_loss: 0.9823 | g_loss: 1.1892; g_d_out min/max = -5.99 / 3.89
# Epoch   24/  50 | d_loss: 0.3246 | g_loss: 5.6378; g_d_out min/max = -10.62 / -2.39
# Epoch   24/  50 | d_loss: 0.2193 | g_loss: 3.7735; g_d_out min/max = -6.79 / -0.16
# Epoch   24/  50 | d_loss: 0.2583 | g_loss: 4.8619; g_d_out min/max = -9.05 / -1.07
# Epoch   24/  50 | d_loss: 0.1490 | g_loss: 4.8310; g_d_out min/max = -10.66 / -1.79
# Epoch   24/  50 | d_loss: 0.6205 | g_loss: 5.4144; g_d_out min/max = -9.45 / -2.27
# Epoch   24/  50 | d_loss: 0.6472 | g_loss: 2.7097; g_d_out min/max = -7.27 / 5.60
# Epoch   24/  50 | d_loss: 0.1824 | g_loss: 4.4452; g_d_out min/max = -11.14 / 0.12
# Epoch   25/  50 | d_loss: 0.5951 | g_loss: 6.6769; g_d_out min/max = -17.51 / -4.14
# Epoch   25/  50 | d_loss: 0.4712 | g_loss: 1.3785; g_d_out min/max = -3.31 / 2.39
# Epoch   25/  50 | d_loss: 0.3673 | g_loss: 4.4413; g_d_out min/max = -9.91 / 0.29
# Epoch   25/  50 | d_loss: 0.2958 | g_loss: 5.1470; g_d_out min/max = -9.05 / -2.03
# Epoch   25/  50 | d_loss: 0.5541 | g_loss: 4.9832; g_d_out min/max = -20.71 / -1.82
# Epoch   25/  50 | d_loss: 0.4018 | g_loss: 4.2658; g_d_out min/max = -7.41 / -0.58
# Epoch   25/  50 | d_loss: 0.2121 | g_loss: 3.9667; g_d_out min/max = -7.74 / -2.20
# Epoch   25/  50 | d_loss: 1.1428 | g_loss: 5.3617; g_d_out min/max = -8.48 / -1.93
# Epoch   25/  50 | d_loss: 0.8906 | g_loss: 1.4615; g_d_out min/max = -5.09 / 1.83
# Epoch   25/  50 | d_loss: 0.5140 | g_loss: 4.4236; g_d_out min/max = -8.87 / -0.27
# Epoch   25/  50 | d_loss: 0.4046 | g_loss: 2.6309; g_d_out min/max = -5.44 / 0.69
# Epoch   26/  50 | d_loss: 0.1501 | g_loss: 5.3993; g_d_out min/max = -9.93 / -2.55
# Epoch   26/  50 | d_loss: 0.5092 | g_loss: 5.3680; g_d_out min/max = -10.71 / -1.27
# Epoch   26/  50 | d_loss: 0.3380 | g_loss: 3.8140; g_d_out min/max = -10.20 / -1.65
# Epoch   26/  50 | d_loss: 0.2698 | g_loss: 5.6766; g_d_out min/max = -10.13 / -2.30
# Epoch   26/  50 | d_loss: 0.3101 | g_loss: 5.1875; g_d_out min/max = -11.36 / -1.27
# Epoch   26/  50 | d_loss: 0.3425 | g_loss: 3.9230; g_d_out min/max = -7.69 / 2.48
# Epoch   26/  50 | d_loss: 0.1919 | g_loss: 3.1516; g_d_out min/max = -11.36 / -1.10
# Epoch   26/  50 | d_loss: 0.1451 | g_loss: 4.3015; g_d_out min/max = -11.04 / 0.02
# Epoch   26/  50 | d_loss: 0.3725 | g_loss: 4.6425; g_d_out min/max = -11.07 / -1.94
# Epoch   26/  50 | d_loss: 0.2347 | g_loss: 5.2043; g_d_out min/max = -12.06 / -0.97
# Epoch   26/  50 | d_loss: 0.3942 | g_loss: 2.9799; g_d_out min/max = -9.01 / 0.03
# Epoch   27/  50 | d_loss: 0.2546 | g_loss: 2.1261; g_d_out min/max = -7.17 / 3.95
# Epoch   27/  50 | d_loss: 0.5346 | g_loss: 2.5075; g_d_out min/max = -6.03 / 2.29
# Epoch   27/  50 | d_loss: 0.1727 | g_loss: 4.6146; g_d_out min/max = -7.37 / -0.02
# Epoch   27/  50 | d_loss: 0.3251 | g_loss: 3.1456; g_d_out min/max = -8.41 / 1.65
# Epoch   27/  50 | d_loss: 0.4506 | g_loss: 5.2506; g_d_out min/max = -9.32 / -1.84
# Epoch   27/  50 | d_loss: 0.5152 | g_loss: 1.9645; g_d_out min/max = -4.89 / 1.97
# Epoch   27/  50 | d_loss: 0.2213 | g_loss: 4.4759; g_d_out min/max = -8.73 / -1.65
# Epoch   27/  50 | d_loss: 0.2536 | g_loss: 3.3155; g_d_out min/max = -10.31 / -0.47
# Epoch   27/  50 | d_loss: 0.3962 | g_loss: 3.6289; g_d_out min/max = -9.18 / 0.48
# Epoch   27/  50 | d_loss: 0.7644 | g_loss: 2.5034; g_d_out min/max = -6.36 / 0.49
# Epoch   27/  50 | d_loss: 0.2618 | g_loss: 2.3779; g_d_out min/max = -6.25 / 2.22
# Epoch   28/  50 | d_loss: 0.2798 | g_loss: 4.0804; g_d_out min/max = -6.89 / 0.37
# Epoch   28/  50 | d_loss: 0.0503 | g_loss: 6.1071; g_d_out min/max = -12.30 / -3.34
# Epoch   28/  50 | d_loss: 0.3172 | g_loss: 3.1483; g_d_out min/max = -7.64 / 1.40
# Epoch   28/  50 | d_loss: 0.6210 | g_loss: 5.3322; g_d_out min/max = -9.05 / -2.84
# Epoch   28/  50 | d_loss: 0.1047 | g_loss: 3.3320; g_d_out min/max = -6.74 / 0.18
# Epoch   28/  50 | d_loss: 0.7129 | g_loss: 4.1442; g_d_out min/max = -7.96 / -1.70
# Epoch   28/  50 | d_loss: 0.4187 | g_loss: 5.5051; g_d_out min/max = -15.91 / -1.63
# Epoch   28/  50 | d_loss: 0.7129 | g_loss: 7.3327; g_d_out min/max = -12.04 / -3.93
# Epoch   28/  50 | d_loss: 0.3000 | g_loss: 3.8940; g_d_out min/max = -8.48 / 0.90
# Epoch   28/  50 | d_loss: 0.1641 | g_loss: 3.4614; g_d_out min/max = -13.72 / 2.75
# Epoch   28/  50 | d_loss: 0.3096 | g_loss: 2.6936; g_d_out min/max = -6.64 / 0.06
# Epoch   29/  50 | d_loss: 0.1054 | g_loss: 4.7336; g_d_out min/max = -9.66 / -2.66
# Epoch   29/  50 | d_loss: 0.2095 | g_loss: 6.1516; g_d_out min/max = -12.11 / -3.35
# Epoch   29/  50 | d_loss: 1.1529 | g_loss: 1.3814; g_d_out min/max = -4.71 / 4.02
# Epoch   29/  50 | d_loss: 0.2599 | g_loss: 1.9923; g_d_out min/max = -12.22 / 2.77
# Epoch   29/  50 | d_loss: 0.4804 | g_loss: 4.4902; g_d_out min/max = -9.26 / -0.65
# Epoch   29/  50 | d_loss: 0.2713 | g_loss: 4.7085; g_d_out min/max = -9.73 / -0.92
# Epoch   29/  50 | d_loss: 0.9752 | g_loss: 5.4493; g_d_out min/max = -8.38 / -2.31
# Epoch   29/  50 | d_loss: 0.7784 | g_loss: 5.1234; g_d_out min/max = -9.91 / 2.19
# Epoch   29/  50 | d_loss: 0.4695 | g_loss: 1.4969; g_d_out min/max = -4.58 / 2.73
# Epoch   29/  50 | d_loss: 1.5850 | g_loss: 2.1018; g_d_out min/max = -6.10 / 0.93
# Epoch   29/  50 | d_loss: 0.5680 | g_loss: 2.6357; g_d_out min/max = -7.71 / 0.13
# Epoch   30/  50 | d_loss: 0.3496 | g_loss: 4.0276; g_d_out min/max = -6.94 / -1.88
# Epoch   30/  50 | d_loss: 0.2674 | g_loss: 5.6901; g_d_out min/max = -11.56 / -1.83
# Epoch   30/  50 | d_loss: 0.0557 | g_loss: 5.0404; g_d_out min/max = -12.94 / -0.87
# Epoch   30/  50 | d_loss: 0.8281 | g_loss: 4.7217; g_d_out min/max = -11.29 / -0.15
# Epoch   30/  50 | d_loss: 0.1439 | g_loss: 5.5657; g_d_out min/max = -8.82 / -1.24
# Epoch   30/  50 | d_loss: 0.1774 | g_loss: 3.7411; g_d_out min/max = -11.06 / 2.02
# Epoch   30/  50 | d_loss: 0.3727 | g_loss: 4.1727; g_d_out min/max = -23.60 / 0.45
# Epoch   30/  50 | d_loss: 0.0630 | g_loss: 5.5771; g_d_out min/max = -8.39 / -2.30
# Epoch   30/  50 | d_loss: 0.1435 | g_loss: 2.3817; g_d_out min/max = -13.65 / 1.85
# Epoch   30/  50 | d_loss: 0.1369 | g_loss: 2.4466; g_d_out min/max = -9.26 / 1.13
# Epoch   30/  50 | d_loss: 0.1412 | g_loss: 4.4935; g_d_out min/max = -8.38 / 4.27
# Epoch   31/  50 | d_loss: 0.2112 | g_loss: 2.8822; g_d_out min/max = -8.07 / 1.90
# Epoch   31/  50 | d_loss: 1.3654 | g_loss: 2.8323; g_d_out min/max = -6.62 / 0.08
# Epoch   31/  50 | d_loss: 0.3414 | g_loss: 3.9740; g_d_out min/max = -8.65 / -1.08
# Epoch   31/  50 | d_loss: 0.1572 | g_loss: 7.0314; g_d_out min/max = -19.90 / -2.48
# Epoch   31/  50 | d_loss: 0.3551 | g_loss: 5.1279; g_d_out min/max = -9.16 / -1.81
# Epoch   31/  50 | d_loss: 1.0566 | g_loss: 5.3276; g_d_out min/max = -9.64 / -1.32
# Epoch   31/  50 | d_loss: 0.1743 | g_loss: 5.2239; g_d_out min/max = -10.13 / -1.16
# Epoch   31/  50 | d_loss: 0.2510 | g_loss: 3.7100; g_d_out min/max = -6.71 / -0.06
# Epoch   31/  50 | d_loss: 0.5133 | g_loss: 4.5914; g_d_out min/max = -18.32 / 2.48
# Epoch   31/  50 | d_loss: 0.2834 | g_loss: 4.8834; g_d_out min/max = -11.15 / -1.36
# Epoch   31/  50 | d_loss: 0.5715 | g_loss: 3.9445; g_d_out min/max = -10.02 / 0.40
# Epoch   32/  50 | d_loss: 0.0748 | g_loss: 5.0083; g_d_out min/max = -9.54 / -2.04
# Epoch   32/  50 | d_loss: 1.0852 | g_loss: 2.2835; g_d_out min/max = -6.46 / 2.06
# Epoch   32/  50 | d_loss: 0.2814 | g_loss: 3.9255; g_d_out min/max = -14.10 / 0.13
# Epoch   32/  50 | d_loss: 0.0981 | g_loss: 3.4270; g_d_out min/max = -15.80 / 0.23
# Epoch   32/  50 | d_loss: 0.2108 | g_loss: 5.8347; g_d_out min/max = -10.67 / -2.94
# Epoch   32/  50 | d_loss: 0.5344 | g_loss: 3.1921; g_d_out min/max = -11.57 / 1.13
# Epoch   32/  50 | d_loss: 0.1222 | g_loss: 4.5979; g_d_out min/max = -6.76 / -1.83
# Epoch   32/  50 | d_loss: 0.1844 | g_loss: 3.0973; g_d_out min/max = -7.42 / 0.51
# Epoch   32/  50 | d_loss: 0.2787 | g_loss: 2.6832; g_d_out min/max = -8.80 / 2.58
# Epoch   32/  50 | d_loss: 0.4461 | g_loss: 2.8743; g_d_out min/max = -10.81 / 2.32
# Epoch   32/  50 | d_loss: 0.2161 | g_loss: 7.4202; g_d_out min/max = -15.24 / -2.90
# Epoch   33/  50 | d_loss: 0.5032 | g_loss: 4.8209; g_d_out min/max = -11.91 / -0.31
# Epoch   33/  50 | d_loss: 0.4454 | g_loss: 4.2237; g_d_out min/max = -8.20 / -0.75
# Epoch   33/  50 | d_loss: 0.5510 | g_loss: 6.4172; g_d_out min/max = -10.42 / -2.77
# Epoch   33/  50 | d_loss: 0.6800 | g_loss: 5.9573; g_d_out min/max = -10.24 / -2.32
# Epoch   33/  50 | d_loss: 1.3589 | g_loss: 3.4119; g_d_out min/max = -8.18 / 1.54
# Epoch   33/  50 | d_loss: 0.6879 | g_loss: 7.5355; g_d_out min/max = -17.35 / -1.06
# Epoch   33/  50 | d_loss: 0.0409 | g_loss: 3.7535; g_d_out min/max = -10.25 / 0.56
# Epoch   33/  50 | d_loss: 0.3292 | g_loss: 3.7997; g_d_out min/max = -7.92 / 0.47
# Epoch   33/  50 | d_loss: 0.1938 | g_loss: 5.3975; g_d_out min/max = -11.13 / -1.54
# Epoch   33/  50 | d_loss: 0.3598 | g_loss: 3.8543; g_d_out min/max = -10.32 / 1.94
# Epoch   33/  50 | d_loss: 0.4562 | g_loss: 4.4057; g_d_out min/max = -9.63 / 0.19
# Epoch   34/  50 | d_loss: 0.4596 | g_loss: 4.8406; g_d_out min/max = -9.53 / -0.68
# Epoch   34/  50 | d_loss: 0.1811 | g_loss: 3.3539; g_d_out min/max = -7.21 / -0.40
# Epoch   34/  50 | d_loss: 0.1993 | g_loss: 5.2331; g_d_out min/max = -8.47 / 1.63
# Epoch   34/  50 | d_loss: 0.1511 | g_loss: 5.0414; g_d_out min/max = -12.55 / -0.88
# Epoch   34/  50 | d_loss: 0.1120 | g_loss: 5.8176; g_d_out min/max = -8.94 / -3.20
# Epoch   34/  50 | d_loss: 0.3018 | g_loss: 4.4182; g_d_out min/max = -11.37 / -1.10
# Epoch   34/  50 | d_loss: 0.1006 | g_loss: 4.3872; g_d_out min/max = -9.43 / -0.73
# Epoch   34/  50 | d_loss: 0.0377 | g_loss: 6.1280; g_d_out min/max = -14.03 / -1.34
# Epoch   34/  50 | d_loss: 0.2859 | g_loss: 5.1636; g_d_out min/max = -23.91 / -0.12
# Epoch   34/  50 | d_loss: 0.5503 | g_loss: 2.9247; g_d_out min/max = -14.78 / 2.95
# Epoch   34/  50 | d_loss: 0.1747 | g_loss: 7.4937; g_d_out min/max = -12.77 / -3.32
# Epoch   35/  50 | d_loss: 0.3984 | g_loss: 3.4494; g_d_out min/max = -8.62 / 0.94
# Epoch   35/  50 | d_loss: 0.3489 | g_loss: 6.2223; g_d_out min/max = -11.71 / -1.37
# Epoch   35/  50 | d_loss: 0.1067 | g_loss: 3.5300; g_d_out min/max = -8.97 / 1.09
# Epoch   35/  50 | d_loss: 1.0877 | g_loss: 6.3154; g_d_out min/max = -12.89 / -3.24
# Epoch   35/  50 | d_loss: 0.4319 | g_loss: 4.5475; g_d_out min/max = -8.44 / -0.87
# Epoch   35/  50 | d_loss: 0.0515 | g_loss: 4.6759; g_d_out min/max = -7.98 / 3.72
# Epoch   35/  50 | d_loss: 0.1984 | g_loss: 3.9060; g_d_out min/max = -10.04 / -0.19
# Epoch   35/  50 | d_loss: 0.1889 | g_loss: 3.1175; g_d_out min/max = -7.51 / 0.63
# Epoch   35/  50 | d_loss: 0.1563 | g_loss: 2.6251; g_d_out min/max = -5.76 / 2.97
# Epoch   35/  50 | d_loss: 0.4078 | g_loss: 3.8080; g_d_out min/max = -10.45 / 0.34
# Epoch   35/  50 | d_loss: 0.3441 | g_loss: 4.9436; g_d_out min/max = -12.95 / -1.01
# Epoch   36/  50 | d_loss: 0.1287 | g_loss: 5.5415; g_d_out min/max = -13.79 / -0.92
# Epoch   36/  50 | d_loss: 0.7381 | g_loss: 2.6639; g_d_out min/max = -8.09 / 2.15
# Epoch   36/  50 | d_loss: 0.3821 | g_loss: 5.1751; g_d_out min/max = -9.10 / -1.12
# Epoch   36/  50 | d_loss: 0.6047 | g_loss: 3.7333; g_d_out min/max = -7.75 / -0.18
# Epoch   36/  50 | d_loss: 0.1830 | g_loss: 4.0967; g_d_out min/max = -9.87 / -0.13
# Epoch   36/  50 | d_loss: 0.1879 | g_loss: 5.4403; g_d_out min/max = -9.12 / -1.29
# Epoch   36/  50 | d_loss: 0.1712 | g_loss: 4.1958; g_d_out min/max = -10.93 / 0.36
# Epoch   36/  50 | d_loss: 0.0656 | g_loss: 4.0157; g_d_out min/max = -13.36 / 1.13
# Epoch   36/  50 | d_loss: 1.7402 | g_loss: 5.7785; g_d_out min/max = -11.52 / -1.83
# Epoch   36/  50 | d_loss: 0.4754 | g_loss: 3.8554; g_d_out min/max = -10.91 / -0.04
# Epoch   36/  50 | d_loss: 0.2543 | g_loss: 4.4221; g_d_out min/max = -8.46 / -1.07
# Epoch   37/  50 | d_loss: 0.1232 | g_loss: 5.0042; g_d_out min/max = -8.15 / -1.80
# Epoch   37/  50 | d_loss: 0.2346 | g_loss: 2.8684; g_d_out min/max = -10.58 / 2.09
# Epoch   37/  50 | d_loss: 0.4542 | g_loss: 2.5580; g_d_out min/max = -6.38 / 1.04
# Epoch   37/  50 | d_loss: 0.1481 | g_loss: 3.3055; g_d_out min/max = -8.95 / 2.01
# Epoch   37/  50 | d_loss: 0.1448 | g_loss: 3.7286; g_d_out min/max = -8.94 / -0.51
# Epoch   37/  50 | d_loss: 0.1550 | g_loss: 4.8797; g_d_out min/max = -11.71 / -1.50
# Epoch   37/  50 | d_loss: 0.0483 | g_loss: 3.1003; g_d_out min/max = -9.10 / 0.29
# Epoch   37/  50 | d_loss: 0.2664 | g_loss: 2.7653; g_d_out min/max = -8.21 / 3.45
# Epoch   37/  50 | d_loss: 0.1285 | g_loss: 5.4443; g_d_out min/max = -14.18 / -1.21
# Epoch   37/  50 | d_loss: 0.0220 | g_loss: 3.3957; g_d_out min/max = -10.45 / 7.30
# Epoch   37/  50 | d_loss: 0.2722 | g_loss: 5.5316; g_d_out min/max = -11.83 / -2.20
# Epoch   38/  50 | d_loss: 0.1912 | g_loss: 4.9194; g_d_out min/max = -10.10 / -1.04
# Epoch   38/  50 | d_loss: 0.0823 | g_loss: 6.3726; g_d_out min/max = -12.61 / -3.52
# Epoch   38/  50 | d_loss: 0.4356 | g_loss: 2.4692; g_d_out min/max = -7.31 / 8.02
# Epoch   38/  50 | d_loss: 0.1867 | g_loss: 5.8167; g_d_out min/max = -10.97 / -2.62
# Epoch   38/  50 | d_loss: 0.2105 | g_loss: 4.5085; g_d_out min/max = -8.65 / -1.42
# Epoch   38/  50 | d_loss: 0.0874 | g_loss: 5.6782; g_d_out min/max = -18.71 / -1.51
# Epoch   38/  50 | d_loss: 0.3729 | g_loss: 6.2764; g_d_out min/max = -10.64 / -2.24
# Epoch   38/  50 | d_loss: 0.1196 | g_loss: 5.7683; g_d_out min/max = -10.76 / 1.14
# Epoch   38/  50 | d_loss: 0.1755 | g_loss: 3.2783; g_d_out min/max = -11.31 / 2.20
# Epoch   38/  50 | d_loss: 0.2316 | g_loss: 3.0089; g_d_out min/max = -19.28 / -0.55
# Epoch   38/  50 | d_loss: 0.3632 | g_loss: 3.0626; g_d_out min/max = -11.18 / 6.38
# Epoch   39/  50 | d_loss: 0.1140 | g_loss: 6.0973; g_d_out min/max = -11.37 / -1.05
# Epoch   39/  50 | d_loss: 0.3760 | g_loss: 2.6042; g_d_out min/max = -5.48 / 6.38
# Epoch   39/  50 | d_loss: 0.1240 | g_loss: 5.3868; g_d_out min/max = -9.90 / -2.03
# Epoch   39/  50 | d_loss: 0.2124 | g_loss: 5.8880; g_d_out min/max = -15.10 / -2.29
# Epoch   39/  50 | d_loss: 0.2902 | g_loss: 6.2867; g_d_out min/max = -15.39 / -2.04
# Epoch   39/  50 | d_loss: 0.3952 | g_loss: 4.1021; g_d_out min/max = -9.67 / 1.48
# Epoch   39/  50 | d_loss: 0.1745 | g_loss: 4.5424; g_d_out min/max = -9.20 / -1.21
# Epoch   39/  50 | d_loss: 0.7591 | g_loss: 3.6443; g_d_out min/max = -8.40 / 1.73
# Epoch   39/  50 | d_loss: 0.1798 | g_loss: 7.3541; g_d_out min/max = -13.22 / -3.75
# Epoch   39/  50 | d_loss: 0.0534 | g_loss: 4.4440; g_d_out min/max = -10.15 / -0.79
# Epoch   39/  50 | d_loss: 0.4080 | g_loss: 4.0152; g_d_out min/max = -16.50 / 5.45
# Epoch   40/  50 | d_loss: 0.7892 | g_loss: 5.0495; g_d_out min/max = -10.17 / 1.86
# Epoch   40/  50 | d_loss: 0.1804 | g_loss: 5.5427; g_d_out min/max = -12.70 / -1.47
# Epoch   40/  50 | d_loss: 0.0631 | g_loss: 6.3881; g_d_out min/max = -11.07 / -3.15
# Epoch   40/  50 | d_loss: 0.1170 | g_loss: 4.0539; g_d_out min/max = -7.66 / 0.46
# Epoch   40/  50 | d_loss: 0.1418 | g_loss: 3.7006; g_d_out min/max = -8.18 / 0.64
# Epoch   40/  50 | d_loss: 0.2684 | g_loss: 6.6452; g_d_out min/max = -13.13 / -3.53
# Epoch   40/  50 | d_loss: 0.1908 | g_loss: 5.7381; g_d_out min/max = -12.84 / -1.90
# Epoch   40/  50 | d_loss: 0.1182 | g_loss: 4.2870; g_d_out min/max = -10.97 / 1.22
# Epoch   40/  50 | d_loss: 0.1123 | g_loss: 6.4128; g_d_out min/max = -13.51 / -1.57
# Epoch   40/  50 | d_loss: 0.4457 | g_loss: 5.9926; g_d_out min/max = -11.63 / -1.34
# Epoch   40/  50 | d_loss: 0.1329 | g_loss: 6.1431; g_d_out min/max = -14.37 / -0.73
# Epoch   41/  50 | d_loss: 0.1451 | g_loss: 2.4087; g_d_out min/max = -8.94 / 2.53
# Epoch   41/  50 | d_loss: 0.1674 | g_loss: 9.1607; g_d_out min/max = -18.70 / -4.09
# Epoch   41/  50 | d_loss: 0.5596 | g_loss: 6.8402; g_d_out min/max = -16.25 / -3.40
# Epoch   41/  50 | d_loss: 0.0638 | g_loss: 4.2551; g_d_out min/max = -10.52 / -0.59
# Epoch   41/  50 | d_loss: 0.5615 | g_loss: 4.5169; g_d_out min/max = -14.26 / -0.33
# Epoch   41/  50 | d_loss: 0.1410 | g_loss: 5.6313; g_d_out min/max = -12.50 / -2.19
# Epoch   41/  50 | d_loss: 0.2120 | g_loss: 4.7256; g_d_out min/max = -11.49 / -0.03
# Epoch   41/  50 | d_loss: 0.2085 | g_loss: 5.1168; g_d_out min/max = -8.90 / 0.22
# Epoch   41/  50 | d_loss: 0.1819 | g_loss: 5.6859; g_d_out min/max = -11.22 / 0.32
# Epoch   41/  50 | d_loss: 0.1428 | g_loss: 5.8460; g_d_out min/max = -11.46 / -0.45
# Epoch   41/  50 | d_loss: 0.2264 | g_loss: 9.3651; g_d_out min/max = -18.18 / -6.14
# Epoch   42/  50 | d_loss: 0.4600 | g_loss: 8.2026; g_d_out min/max = -20.18 / -3.35
# Epoch   42/  50 | d_loss: 0.0518 | g_loss: 4.6876; g_d_out min/max = -9.13 / 1.55
# Epoch   42/  50 | d_loss: 0.0776 | g_loss: 6.4839; g_d_out min/max = -11.08 / -2.01
# Epoch   42/  50 | d_loss: 1.8301 | g_loss: 7.3546; g_d_out min/max = -12.15 / -4.21
# Epoch   42/  50 | d_loss: 0.0374 | g_loss: 6.2438; g_d_out min/max = -11.80 / -2.17
# Epoch   42/  50 | d_loss: 0.2843 | g_loss: 4.0596; g_d_out min/max = -10.78 / 1.11
# Epoch   42/  50 | d_loss: 0.3387 | g_loss: 5.4094; g_d_out min/max = -14.82 / -1.56
# Epoch   42/  50 | d_loss: 0.1518 | g_loss: 5.8600; g_d_out min/max = -11.47 / -2.88
# Epoch   42/  50 | d_loss: 0.2832 | g_loss: 4.5233; g_d_out min/max = -8.34 / 0.88
# Epoch   42/  50 | d_loss: 0.2723 | g_loss: 8.9701; g_d_out min/max = -27.64 / -2.24
# Epoch   42/  50 | d_loss: 0.2136 | g_loss: 5.7521; g_d_out min/max = -10.19 / 0.33
# Epoch   43/  50 | d_loss: 0.1635 | g_loss: 4.5715; g_d_out min/max = -12.01 / -1.31
# Epoch   43/  50 | d_loss: 0.0889 | g_loss: 5.8971; g_d_out min/max = -12.10 / -1.45
# Epoch   43/  50 | d_loss: 0.0777 | g_loss: 3.7488; g_d_out min/max = -7.63 / 1.36
# Epoch   43/  50 | d_loss: 0.2249 | g_loss: 4.4930; g_d_out min/max = -10.47 / 0.74
# Epoch   43/  50 | d_loss: 0.3420 | g_loss: 5.2757; g_d_out min/max = -9.37 / -1.18
# Epoch   43/  50 | d_loss: 0.9009 | g_loss: 3.2046; g_d_out min/max = -11.24 / 1.82
# Epoch   43/  50 | d_loss: 0.1598 | g_loss: 3.8849; g_d_out min/max = -7.13 / -1.04
# Epoch   43/  50 | d_loss: 0.2416 | g_loss: 4.6109; g_d_out min/max = -7.91 / 1.14
# Epoch   43/  50 | d_loss: 0.1997 | g_loss: 4.8430; g_d_out min/max = -10.27 / -1.77
# Epoch   43/  50 | d_loss: 0.6124 | g_loss: 2.5357; g_d_out min/max = -6.08 / 2.40
# Epoch   43/  50 | d_loss: 0.5545 | g_loss: 3.0862; g_d_out min/max = -7.11 / 1.39
# Epoch   44/  50 | d_loss: 0.1242 | g_loss: 7.1584; g_d_out min/max = -12.38 / -3.47
# Epoch   44/  50 | d_loss: 0.2236 | g_loss: 4.8108; g_d_out min/max = -9.96 / -0.76
# Epoch   44/  50 | d_loss: 0.2870 | g_loss: 6.9119; g_d_out min/max = -12.53 / -3.08
# Epoch   44/  50 | d_loss: 0.3405 | g_loss: 3.3447; g_d_out min/max = -10.17 / 0.15
# Epoch   44/  50 | d_loss: 0.0194 | g_loss: 6.6354; g_d_out min/max = -12.33 / -1.73
# Epoch   44/  50 | d_loss: 0.0346 | g_loss: 4.5938; g_d_out min/max = -12.41 / -1.20
# Epoch   44/  50 | d_loss: 0.2420 | g_loss: 3.5791; g_d_out min/max = -8.93 / 0.93
# Epoch   44/  50 | d_loss: 0.0337 | g_loss: 5.1179; g_d_out min/max = -9.39 / 0.13
# Epoch   44/  50 | d_loss: 0.0887 | g_loss: 4.2982; g_d_out min/max = -7.55 / -1.35
# Epoch   44/  50 | d_loss: 0.0827 | g_loss: 4.8037; g_d_out min/max = -11.55 / 0.28
# Epoch   44/  50 | d_loss: 1.3702 | g_loss: 1.7506; g_d_out min/max = -4.17 / 3.83
# Epoch   45/  50 | d_loss: 0.0382 | g_loss: 5.6414; g_d_out min/max = -11.76 / -2.11
# Epoch   45/  50 | d_loss: 0.1569 | g_loss: 6.5102; g_d_out min/max = -13.38 / -2.15
# Epoch   45/  50 | d_loss: 0.1464 | g_loss: 4.3339; g_d_out min/max = -10.21 / 2.13
# Epoch   45/  50 | d_loss: 0.0939 | g_loss: 5.0793; g_d_out min/max = -11.28 / -0.15
# Epoch   45/  50 | d_loss: 0.3856 | g_loss: 5.6534; g_d_out min/max = -16.44 / -1.83
# Epoch   45/  50 | d_loss: 0.1507 | g_loss: 6.7706; g_d_out min/max = -15.88 / -2.08
# Epoch   45/  50 | d_loss: 0.3745 | g_loss: 7.6075; g_d_out min/max = -14.87 / -3.90
# Epoch   45/  50 | d_loss: 0.5969 | g_loss: 5.1879; g_d_out min/max = -14.08 / -1.32
# Epoch   45/  50 | d_loss: 0.1719 | g_loss: 5.4195; g_d_out min/max = -11.12 / -1.45
# Epoch   45/  50 | d_loss: 0.0786 | g_loss: 6.4020; g_d_out min/max = -11.23 / -1.40
# Epoch   45/  50 | d_loss: 0.2361 | g_loss: 7.6447; g_d_out min/max = -13.30 / -3.35
# Epoch   46/  50 | d_loss: 0.2204 | g_loss: 5.9152; g_d_out min/max = -10.91 / -1.64
# Epoch   46/  50 | d_loss: 0.1863 | g_loss: 5.0751; g_d_out min/max = -10.63 / -1.46
# Epoch   46/  50 | d_loss: 0.2093 | g_loss: 5.0261; g_d_out min/max = -9.12 / -1.12
# Epoch   46/  50 | d_loss: 0.0233 | g_loss: 5.6082; g_d_out min/max = -16.17 / -1.15
# Epoch   46/  50 | d_loss: 0.1315 | g_loss: 8.4105; g_d_out min/max = -15.75 / -3.27
# Epoch   46/  50 | d_loss: 0.2560 | g_loss: 2.4392; g_d_out min/max = -13.79 / 7.03
# Epoch   46/  50 | d_loss: 0.3401 | g_loss: 7.0881; g_d_out min/max = -13.25 / -3.06
# Epoch   46/  50 | d_loss: 0.0925 | g_loss: 3.8445; g_d_out min/max = -9.32 / 1.26
# Epoch   46/  50 | d_loss: 0.1194 | g_loss: 6.4403; g_d_out min/max = -15.41 / -0.66
# Epoch   46/  50 | d_loss: 0.1064 | g_loss: 5.2953; g_d_out min/max = -12.24 / -1.24
# Epoch   46/  50 | d_loss: 0.1490 | g_loss: 4.7804; g_d_out min/max = -13.35 / 0.83
# Epoch   47/  50 | d_loss: 0.1584 | g_loss: 8.1233; g_d_out min/max = -11.39 / -2.76
# Epoch   47/  50 | d_loss: 2.3734 | g_loss: 8.1535; g_d_out min/max = -17.57 / -1.51
# Epoch   47/  50 | d_loss: 0.2585 | g_loss: 4.8365; g_d_out min/max = -9.89 / 0.49
# Epoch   47/  50 | d_loss: 0.0713 | g_loss: 4.7894; g_d_out min/max = -11.34 / -1.68
# Epoch   47/  50 | d_loss: 0.2946 | g_loss: 5.4930; g_d_out min/max = -11.34 / -1.63
# Epoch   47/  50 | d_loss: 0.0985 | g_loss: 6.2987; g_d_out min/max = -13.85 / -2.06
# Epoch   47/  50 | d_loss: 1.0099 | g_loss: 4.9549; g_d_out min/max = -9.52 / -0.22
# Epoch   47/  50 | d_loss: 0.3991 | g_loss: 6.4289; g_d_out min/max = -16.05 / -0.25
# Epoch   47/  50 | d_loss: 0.2018 | g_loss: 5.3256; g_d_out min/max = -9.94 / 1.46
# Epoch   47/  50 | d_loss: 0.1614 | g_loss: 3.2744; g_d_out min/max = -8.15 / 1.85
# Epoch   47/  50 | d_loss: 0.0926 | g_loss: 5.5759; g_d_out min/max = -11.87 / -1.70
# Epoch   48/  50 | d_loss: 0.1437 | g_loss: 2.0451; g_d_out min/max = -6.22 / 2.53
# Epoch   48/  50 | d_loss: 0.5605 | g_loss: 4.2106; g_d_out min/max = -9.51 / 0.14
# Epoch   48/  50 | d_loss: 0.2935 | g_loss: 4.3412; g_d_out min/max = -9.03 / -0.57
# Epoch   48/  50 | d_loss: 0.0993 | g_loss: 5.0988; g_d_out min/max = -16.53 / 0.56
# Epoch   48/  50 | d_loss: 0.0591 | g_loss: 3.6115; g_d_out min/max = -7.22 / -0.08
# Epoch   48/  50 | d_loss: 0.1738 | g_loss: 5.5257; g_d_out min/max = -12.80 / -1.39
# Epoch   48/  50 | d_loss: 0.1529 | g_loss: 6.6463; g_d_out min/max = -13.91 / -2.98
# Epoch   48/  50 | d_loss: 0.0122 | g_loss: 5.7272; g_d_out min/max = -20.03 / -1.70
# Epoch   48/  50 | d_loss: 0.0137 | g_loss: 6.5468; g_d_out min/max = -10.59 / -3.35
# Epoch   48/  50 | d_loss: 0.1025 | g_loss: 3.8682; g_d_out min/max = -14.93 / 2.29
# Epoch   48/  50 | d_loss: 0.1011 | g_loss: 3.9239; g_d_out min/max = -13.29 / 0.17
# Epoch   49/  50 | d_loss: 0.0264 | g_loss: 6.1993; g_d_out min/max = -10.56 / -0.86
# Epoch   49/  50 | d_loss: 0.3633 | g_loss: 4.0321; g_d_out min/max = -9.75 / 4.47
# Epoch   49/  50 | d_loss: 0.1097 | g_loss: 3.1768; g_d_out min/max = -10.55 / 0.39
# Epoch   49/  50 | d_loss: 0.0221 | g_loss: 2.2952; g_d_out min/max = -9.41 / 2.25
# Epoch   49/  50 | d_loss: 0.1137 | g_loss: 4.5469; g_d_out min/max = -16.88 / 1.13
# Epoch   49/  50 | d_loss: 0.2339 | g_loss: 4.7559; g_d_out min/max = -8.63 / -1.74
# Epoch   49/  50 | d_loss: 0.1463 | g_loss: 6.6882; g_d_out min/max = -11.80 / -0.88
# Epoch   49/  50 | d_loss: 0.3706 | g_loss: 5.5564; g_d_out min/max = -13.16 / -0.41
# Epoch   49/  50 | d_loss: 0.0457 | g_loss: 6.1643; g_d_out min/max = -12.54 / -2.31
# Epoch   49/  50 | d_loss: 0.3694 | g_loss: 3.9197; g_d_out min/max = -8.19 / 0.15
# Epoch   49/  50 | d_loss: 0.1201 | g_loss: 4.9325; g_d_out min/max = -11.82 / 0.73
# Epoch   50/  50 | d_loss: 0.1088 | g_loss: 5.8610; g_d_out min/max = -11.11 / -2.51
# Epoch   50/  50 | d_loss: 0.2608 | g_loss: 4.1716; g_d_out min/max = -8.16 / 0.61
# Epoch   50/  50 | d_loss: 0.1025 | g_loss: 5.2316; g_d_out min/max = -14.33 / -2.44
# Epoch   50/  50 | d_loss: 0.0607 | g_loss: 6.1358; g_d_out min/max = -14.94 / -1.73
# Epoch   50/  50 | d_loss: 0.1328 | g_loss: 3.0900; g_d_out min/max = -9.13 / 0.91
# Epoch   50/  50 | d_loss: 0.2885 | g_loss: 2.7947; g_d_out min/max = -7.91 / 1.48
# Epoch   50/  50 | d_loss: 0.1925 | g_loss: 6.3132; g_d_out min/max = -10.28 / -2.20
# Epoch   50/  50 | d_loss: 0.2184 | g_loss: 6.3012; g_d_out min/max = -11.97 / -1.37
# Epoch   50/  50 | d_loss: 0.7787 | g_loss: 7.4927; g_d_out min/max = -15.08 / -3.00
# Epoch   50/  50 | d_loss: 0.0076 | g_loss: 6.1405; g_d_out min/max = -10.81 / -2.92
# Epoch   50/  50 | d_loss: 0.5439 | g_loss: 5.4160; g_d_out min/max = -11.08 / -0.63
# /opt/conda/lib/python3.7/site-packages/torch/storage.py:34: FutureWarning: pickle support for Storage will be removed in 1.5. Use `torch.save` instead
#   warnings.warn("pickle support for Storage will be removed in 1.5. Use `torch.save` instead", FutureWarning)

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)

plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# View samples of images from the generator, and answer a question about the strengths and weaknesses of your trained models.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples, nrows=2):
    fig, axes = plt.subplots(figsize=(16,4), nrows=nrows, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
for i in range(0, n_epochs, 10):
    #print("Epoch {}:".format(i))
    view_samples(i, samples, nrows=1)

# %%
view_samples(-1, samples)

# %% [markdown]
# ### Question: What do you notice about your generated samples and how might you improve this model?
# When you answer this question, consider the following factors:
# * The dataset is biased; it is made of "celebrity" faces that are mostly white
# * Model size; larger models have the opportunity to learn more features in a data feature space
# * Optimization strategy; optimizers and number of epochs affect your final result

# %% [markdown]
# **Answer:** They are slightly blurry, but I attribute that mostly to the small photo size (32x32 pixels is tiny).  Some of them are more blurry than the real samples, but some are comparably "sharp", so I feel the model is doing a good job in terms of edge & feature clarity.  Considering the lack of diversity in the training data, there is surprising variation in the model outputs.  Eyes are pointing different directions, faces are oriented in different angles, general face shape, hair styles and colors seems like a good cross-section of the training data.  Looking at interim results (from early epochs), it seems the model has difficulty regarding facial hair (sometimes on women), but by the final epoch there is no facial hair on women, and the few men who have it it seems realistic.
#
# I initially tried 20 epochs, with good results, but the discriminator loss was still going down at that point.  So I tried 50 epochs and reduced the learning rate a bit to get the results presented here.  I feel they are more realistic.  The discriminator loss is still going down, so still more epochs may be useful.  However, I am concerned about the increasing loss of the generator, which might be the start of it blowing up.
#
# In order to improve the model further, I would like to use larger images for training (128x128 or more), and get more of the face structure (currently, chins and tops of heads are all cropped off).  This should give a little more feature space to learn, as well as present some more background that would have to be filtered out.  I started down this path, but ran into problems with disk space, which will take some time to resolve, so I will have to tackle it another time.

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "problem_unittests.py" files in your submission.
